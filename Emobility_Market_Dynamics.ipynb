# %%
0.48
NaN
0.44
0.37
NaN
0.48
2.43
0.46
0.45
0.41
0.34
0.35
0.36
0.39
0.35
0.44
0.30
0.39
0.55
0.24
0.60
0.69
0.40
0.36
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 0.48
# ----> 2 NaN
#       3 0.44
#       4 0.37
#
# NameError: name 'NaN' is not defined

# %%
# Given data
data = {
    "Country": ["Germany", "Switzerland", "Austria", "France", "UK", "Sweden", "Netherlands", "Norway", "Belgium",
                "Ireland", "Luxembourg", "Denmark", "Italy", "Spain", "Lithuania", "Finland", "Portugal", "Poland",
                "Czech Republic", "Estonia", "Hungary", "Slovenia", "Latvia", "Slovakia"],
    "DC_prices_2022": [0.61, 0.54, 0.59, 0.52, 0.50, 0.58, 0.63, 0.55, 0.62, 0.44, 0.39, 0.60, 0.55, 0.59, 0.61, 0.51,
                       0.40, 0.59, 1.05, 0.52, 0.59, 0.64, 0.67, 0.52],
    "Energy_prices_2022": [0.3279, 0, 0.2249, 0.2092, 0, 0.2278, 0.0451, 0.1994, 0.3437, 0.2324, 0.2017, 0.4559, 0.3115,
                           0.3071, 0.1497, 0.1934, 0.2199, 0.1464, 0.2445, 0.2056, 0.0948, 0.139, 0.1759, 0.1796],
    "Energy_prices_2020": [0.3088, 0, 0.2034, 0.1778, 0, 0.2033, 0.2067, 0.1867, 0.2839, 0.2423, 0.1798, 0.2984, 0.2301,
                           0.2403, 0.1255, 0.1734, 0.2150, 0.1343, 0.1748, 0.1357, 0.1120, 0.1634, 0.1629, 0.1577]
}

df = pd.DataFrame(data)

# Function to calculate DC_prices_2020
def calculate_dc_prices_2020(row):
    if row['Energy_prices_2020'] == 0 or row['Energy_prices_2022'] == 0:
        return None  # Avoid division by zero or undefined values
    proportional_change = row['Energy_prices_2022'] / row['Energy_prices_2020']
    dc_price_2020 = row['DC_prices_2022'] / proportional_change
    return dc_price_2020

# Apply the function to each row
df['DC_prices_2020'] = df.apply(calculate_dc_prices_2020, axis=1)

# Round the DC_prices_2020 to 2 decimal places
df['DC_prices_2020'] = df['DC_prices_2020'].round(2)

import ace_tools as tools; tools.display_dataframe_to_user(name="Updated Energy and DC Prices Table", dataframe=df)

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 14
#       1 # Given data
#       2 data = {
#       3     "Country": ["Germany", "Switzerland", "Austria", "France", "UK", "Sweden", "Netherlands", "Norway", "Belgium",
#       4                 "Ireland", "Luxembourg", "Denmark", "Italy", "Spain", "Lithuania", "Finland", "Portugal", "Poland",
#    (...)
#      11                            0.2403, 0.1255, 0.1734, 0.2150, 0.1343, 0.1748, 0.1357, 0.1120, 0.1634, 0.1629, 0.1577]
#      12 }
# ---> 14 df = pd.DataFrame(data)
#      16 # Function to calculate DC_prices_2020
#      17 def calculate_dc_prices_2020(row):
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# New values from the user
new_values = [
    0.2792, 0.0997, 0.1841, 0.2833, 0.3043, 0.1236, 0.2413, 0.1674, 0.2239, 0.1893, 
    0.1301, 0.2226, 0.2133, 0.1420, 0.1426, 0.1986, 0.1031, 0.1284, 0.1427, 0.2111, 
    0.1475, 0.2120, 0.1459, 0.1448, 0.1686, 0.1740, 0.1914, 0.1341, 0.2115, 0.1355, 
    0, 0.2203
]

# Original data
original_countries = [
    "Belgium", "Bulgaria", "Czechia", "Denmark", "Germany", "Estonia", "Ireland", 
    "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", 
    "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", 
    "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "Iceland", "Liechtenstein", 
    "Norway", "Switzerland", "United Kingdom"
]

# New order of countries
new_order_countries = [
    "Germany", "Switzerland", "Austria", "France", "UK", "Sweden", "Netherlands", 
    "Norway", "Belgium", "Ireland", "Luxembourg", "Denmark", "Italy", "Spain", 
    "Lithuania", "Finland", "Portugal", "Poland", "Czechia", "Estonia", "Hungary", 
    "Slovenia", "Latvia", "Slovakia"
]

# Create a dictionary to map countries to their values
country_value_dict = dict(zip(original_countries, new_values))

# Create a list to store the values in the new order
new_order_values = [country_value_dict.get(country, 0) for country in new_order_countries]

# Create DataFrame
df_new_order = pd.DataFrame({
    "Country": new_order_countries,
    "Value": new_order_values
})

# Save to Excel
file_path = "european_countries_values_new_order_updated.xlsx"
df_new_order.to_excel(file_path, index=False)
# Out:
# /var/folders/d2/6t2p0zp522l3y0s265sql42m0000gn/T/ipykernel_64485/910605889.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd

# Given data
data = {
    "Country": ["Germany", "Switzerland", "Austria", "France", "UK", "Sweden", "Netherlands", "Norway", "Belgium",
                "Ireland", "Luxembourg", "Denmark", "Italy", "Spain", "Lithuania", "Finland", "Portugal", "Poland",
                "Czech Republic", "Estonia", "Hungary", "Slovenia", "Latvia", "Slovakia"],
    "DC_prices_2022": [0.61, 0.54, 0.59, 0.52, 0.50, 0.58, 0.63, 0.55, 0.62, 0.44, 0.39, 0.60, 0.55, 0.59, 0.61, 0.51,
                       0.40, 0.59, 1.05, 0.52, 0.59, 0.64, 0.67, 0.52],
    "Energy_prices_2022": [0.3279, 0, 0.2249, 0.2092, 0, 0.2278, 0.0451, 0.1994, 0.3437, 0.2324, 0.2017, 0.4559, 0.3115,
                           0.3071, 0.1497, 0.1934, 0.2199, 0.1464, 0.2445, 0.2056, 0.0948, 0.139, 0.1759, 0.1796],
    "Energy_prices_2021": [0.3043, 0, 0.2111, 0.1893, 0, 0.1914, 0.1427, 0.1355, 0.2792, 0.2413, 0.1986, 0.2833, 0.2226,
                           0.2239, 0.1426, 0.174, 0.212, 0.1475, 0.1841, 0.1236, 0.1031, 0.1448, 0.142, 0.1686]
}

df = pd.DataFrame(data)

# Function to calculate DC_prices_2021
def calculate_dc_prices_2021(row):
    if row['Energy_prices_2021'] == 0 or row['Energy_prices_2022'] == 0:
        return None  # Avoid division by zero or undefined values
    proportional_change = row['Energy_prices_2022'] / row['Energy_prices_2021']
    dc_price_2021 = row['DC_prices_2022'] / proportional_change
    return dc_price_2021

# Apply the function to each row
df['DC_prices_2021'] = df.apply(calculate_dc_prices_2021, axis=1)

# Round the DC_prices_2021 to 2 decimal places
df['DC_prices_2021'] = df['DC_prices_2021'].round(2)

df.to_excel("DC_prices_2021_calculated.xlsx", index=False)

# %%
import pandas as pd

# New values from the user
new_values = [
    0.2702, 0.1024, 0.1802, 0.2900, 0.3193, 0.1324, 0.2555, 0.1680, 0.2323, 0.1946, 
    0.1291, 0.2259, 0.1976, 0.1403, 0.1348, 0.1988, 0.1010, 0.1285, 0.1281, 0.2216, 
    0.1548, 0.2089, 0.1536, 0.1662, 0.1668, 0.1767, 0.2114, 0.1355, 0.2071, 0.1826, 
    None, None  # None represents no value available
]

# Original data
original_countries = [
    "Belgium", "Bulgaria", "Czech Republic", "Denmark", "Germany", "Estonia", "Ireland", 
    "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", 
    "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", 
    "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "Iceland", "Liechtenstein", 
    "Norway", "Switzerland", "United Kingdom"
]

# New order of countries
new_order_countries = [
    "Germany", "Switzerland", "Austria", "France", "UK", "Sweden", "Netherlands", 
    "Norway", "Belgium", "Ireland", "Luxembourg", "Denmark", "Italy", "Spain", 
    "Lithuania", "Finland", "Portugal", "Poland", "Czech Republic", "Estonia", "Hungary", 
    "Slovenia", "Latvia", "Slovakia"
]

# Create a dictionary to map countries to their values
country_value_dict = dict(zip(original_countries, new_values))

# Create a list to store the values in the new order
new_order_values = [country_value_dict.get(country, 0) for country in new_order_countries]

# Create DataFrame
df_new_order = pd.DataFrame({
    "Country": new_order_countries,
    "Value": new_order_values
})

# Save to Excel
file_path = "european_countries_values_new_order_updated.xlsx"
df_new_order.to_excel(file_path, index=False)

# %%
import pandas as pd

# New values from the user
new_values = [
    0.2702, 0.1024, 0.1802, 0.2900, 0.3193, 0.1324, 0.2555, 0.1680, 0.2323, 0.1946, 
    0.1291, 0.2259, 0.1976, 0.1403, 0.1348, 0.1988, 0.1010, 0.1285, 0.1281, 0.2216, 
    0.1548, 0.2089, 0.1536, 0.1662, 0.1668, 0.1767, 0.2114, 0.1355, 0.2071, 0.1826, 
    None, None  # None represents no value available
]

# Original data
original_countries = [
    "Belgium", "Bulgaria", "Czech Republic", "Denmark", "Germany", "Estonia", "Ireland", 
    "Greece", "Spain", "France", "Croatia", "Italy", "Cyprus", "Latvia", "Lithuania", 
    "Luxembourg", "Hungary", "Malta", "Netherlands", "Austria", "Poland", "Portugal", 
    "Romania", "Slovenia", "Slovakia", "Finland", "Sweden", "Iceland", "Liechtenstein", 
    "Norway", "Switzerland", "United Kingdom"
]

# New order of countries
new_order_countries = [
    "Germany", "Switzerland", "Austria", "France", "UK", "Sweden", "Netherlands", 
    "Norway", "Belgium", "Ireland", "Luxembourg", "Denmark", "Italy", "Spain", 
    "Lithuania", "Finland", "Portugal", "Poland", "Czech Republic", "Estonia", "Hungary", 
    "Slovenia", "Latvia", "Slovakia"
]

# Create a dictionary to map countries to their values
country_value_dict = dict(zip(original_countries, new_values))

# Create a list to store the values in the new order
new_order_values = [country_value_dict.get(country, 0) for country in new_order_countries]

# Create DataFrame
df_new_order = pd.DataFrame({
    "Country": new_order_countries,
    "Value": new_order_values
})

# Save to Excel
file_path = "european_countries_values_new_order_updated.xlsx"
df_new_order.to_excel(file_path, index=False)

# %%
# Define the path to the Excel file
file_path = '/Users/user/Desktop/Thesis /Book1_python_V001.xlsx'

# %%
import pandas as pd
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
df = pd.read_excel(file_path)

# Display the first few rows of the dataset
print("Dataset:")
print(df.head())
# Out:
# Dataset:
#      Countries  Inhabitants      GDPI  \
# 0      Germany     84358845  33700.07
# 1  Switzerland      8815385  33608.93
# 2      Austria      9104772  31711.24
# 3       France     68172977  30437.28
# 4           UK     67500000  26950.42
#
#    Total_Amount_of_publicly_charged_electriy_energy_(kWh)  AC_points  \
# 0                                       1.579693e+09           97704
# 1                                       1.196715e+08           12082
# 2                                       1.467384e+08           15229
# 3                                       6.179227e+06          100767
# 4                                       1.025810e+07           11710
#
#    DC_points  HPC_points  Number_of_EVs  \
# 0      22921       14462        1074821
# 1       2153        1138         104088
# 2       3408        1790          92745
# 3      18488        4583         518815
# 4       6294        3998         604063
#
# ...

# %%
# Define the independent variables
Independent_variable1 = 'Inhabitants'
Independent_variable2 = 'GDPI'
Independent_variable3 = 'Total_Amount_of_publicly_charged_electricity_energy_(kWh)'  # Corrected typo
Independent_variable4 = 'AC_points'
Independent_variable5 = 'DC_points'
Independent_variable6 = 'HPC_points'
Independent_variable7 = 'Amount_of_Evs_in_a_wallbox_household'
Independent_variable8 = 'Amount_of_Evs_charging_only_in_public'
Independent_variable9 = 'Realistic_share_of_wallbox_owners'
Independent_variable10 = 'share_of_the_total_population_with_possibility_to_charge_at_home'
Independent_variable11 = 'AC_charging_price'
Independent_variable12 = 'DC_charging_price'
Independent_variable13 = 'HPC_charging_price'
Independent_variable14 = 'energy_cost'
Independent_variable15 = 'EPI score'

# Define the name of the dependent variable
dependent_variable = 'EV_registrations'

# List of all independent variables
independent_variables = [
    Independent_variable1, Independent_variable2, Independent_variable3,
    Independent_variable4, Independent_variable5, Independent_variable6,
    Independent_variable7, Independent_variable8, Independent_variable9,
    Independent_variable10, Independent_variable11, Independent_variable12,
    Independent_variable13, Independent_variable14
]

# %%
# Function to read sheet if it exists
def read_sheet(sheet_name):
    if sheet_name in sheet_names:
        return pd.read_excel(file_path, sheet_name=sheet_name)
    else:
        print(f"Worksheet named '{sheet_name}' not found.")
        return pd.DataFrame()

# Check the available sheet names in the Excel file
sheet_names = pd.ExcelFile(file_path).sheet_names

# Read data from specified sheets
df_2023 = read_sheet('2023')
df_2022 = read_sheet('2022 ')
df_2021 = read_sheet('2021')
df_2020 = read_sheet('2020')

# %%
# Combine the data into a single DataFrame
df_combined = pd.concat([df_2023, df_2022, df_2021, df_2020], ignore_index=True)

# %%
# Function to read sheet and standardize column names
def read_and_standardize_sheet(sheet_name):
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    standardized_columns = [
        'Countries', 
        'Inhabitants', 
        'GDPI',
        'Total_Amount_of_publicly_charged_electricity_energy_(kWh)', 
        'AC_points',
        'DC_points', 
        'HPC_points',
        'Number_of_EVs',
        'Amount_of_Evs_charging_only_in_public', 
        'EV_registrations',
        'Realistic_share_of_wallbox_owners',
        'share_of_the_total_population_with_possibility_to_charge_at_home',
        'Kilometers_per_year_per_car_(kms.)',
        'kilometers_per_year_all_cars_(km)', 
        'EV_registrations',
        'Amount_of_cars_in_a_year',
        'Amount_of_Evs_in_a_wallbox_household', 
        'AC_charging_price',
        'DC_charging_price', 
        'HPC_charging_price', 
        'energy_cost'
    ]
    df.columns = standardized_columns
    return df

# %%
df_2020.columns
# Out:
# Index(['Countries', 'Inhabitants', 'GDPI',
#        'Total_Amount_of_publicly_charged_electriy_energy_(kWh)', 'AC_points',
#        'DC_points', 'HPC_points', 'Number_of_EVs',
#        'Amount_of_Evs_charging_only_in_public', 'EV_registrations',
#        'Realistic_share_of_wallbox_owners',
#        'share_of_the_total_population_with_possiblity_to_charge_at_home',
#        'Kilometers_per_year_per_car_(kms.)',
#        'kilometers_per_year_all_cars_(km)', 'Amount_of_cars_in_a_year',
#        'Amount_of_Evs_in_a_wallbox_household', 'AC_charging_price',
#        'DC_charging_price', 'HPC_charging_price', 'energy_cost', 'EPI score'],
#       dtype='object')

# %%
pd.read_excel()

# %%
# Read data from specified sheets
df_2023 = read_and_standardize_sheet('2023')
df_2022 = read_and_standardize_sheet('2022 ')
df_2021 = read_and_standardize_sheet('2021')
df_2020 = read_and_standardize_sheet('2020')

# %%
# Replace zeros with NaN to indicate missing data
df_combined.replace(0, pd.NA, inplace=True)

# Separate numeric columns from non-numeric columns
numeric_columns = df_combined.select_dtypes(include=['number']).columns
non_numeric_columns = df_combined.select_dtypes(exclude=['number']).columns

# Fill missing values in numeric columns with the mean
df_combined[numeric_columns] = df_combined[numeric_columns].fillna(df_combined[numeric_columns].mean())

# Fill missing values in non-numeric columns with a placeholder or the most frequent value
df_combined[non_numeric_columns] = df_combined[non_numeric_columns].fillna('Unknown')

# %%
# Correction of Name Typos
# Rename columns from Total_Amount_of_publicly_charged_electriy_energy_(kWh) to Total_Amount_of_publicly_charged_electricity_energy_(kWh)
# Rename columns from share_of_the_total_population_with_possiblity_to_charge_at_home to share_of_the_total_population_with_possibility_to_charge_at_home
df_combined.rename(columns={'Total_Amount_of_publicly_charged_electriy_energy_(kWh)': 'Total_Amount_of_publicly_charged_electricity_energy_(kWh)',
                            'share_of_the_total_population_with_possiblity_to_charge_at_home': 'share_of_the_total_population_with_possibility_to_charge_at_home'}, inplace=True)

# %%
# Check that all the variables are in the DataFrame's columns
missing_columns = [var for var in independent_variables + [dependent_variable] if var not in df_combined.columns]
if missing_columns:
    print("The following columns are missing from the DataFrame: ", missing_columns)
else:
    # If all columns are present, proceed to use them in your analysis
    X = df_combined[independent_variables]
    y = df_combined[dependent_variable]

# %%
print(X.dtypes)
print(y.dtypes)
# Out:
# Inhabitants                                                         float64
# GDPI                                                                 object
# Total_Amount_of_publicly_charged_electricity_energy_(kWh)            object
# AC_points                                                           float64
# DC_points                                                           float64
# HPC_points                                                          float64
# Amount_of_Evs_in_a_wallbox_household                                 object
# Amount_of_Evs_charging_only_in_public                               float64
# Realistic_share_of_wallbox_owners                                   float64
# share_of_the_total_population_with_possibility_to_charge_at_home    float64
# AC_charging_price                                                    object
# DC_charging_price                                                    object
# ...

# %%
X
# Out:
#     Inhabitants      GDPI  \
# 0    84358845.0  33700.07
# 1     8815385.0  33608.93
# 2     9104772.0  31711.24
# 3    68172977.0  30437.28
# 4    67500000.0  26950.42
# ..          ...       ...
# 95    1329000.0   17316.0
# 96    9769526.0   15761.0
# 97    2095900.0   19823.0
# 98    1907700.0   15778.0
# 99    5457900.0   15591.0
#
#    Total_Amount_of_publicly_charged_electricity_energy_(kWh)  AC_points  \
# 0                                    1579692643.88025           97704.0
# 1                                    119671509.471963           12082.0
# 2                                    146738411.403576           15229.0
# 3                                      6179227.010375          100767.0
# 4                                     10258104.726814           11710.0
# ..                                                ...               ...
# 95                                      619604.972136              33.0
# ...

# %%
# Find Unknown in X df and replace with 0
X = X.replace('Unknown', 0)
X
# Out:
#     Inhabitants      GDPI  \
# 0    84358845.0  33700.07
# 1     8815385.0  33608.93
# 2     9104772.0  31711.24
# 3    68172977.0  30437.28
# 4    67500000.0  26950.42
# ..          ...       ...
# 95    1329000.0  17316.00
# 96    9769526.0  15761.00
# 97    2095900.0  19823.00
# 98    1907700.0  15778.00
# 99    5457900.0  15591.00
#
#     Total_Amount_of_publicly_charged_electricity_energy_(kWh)  AC_points  \
# 0                                        1.579693e+09            97704.0
# 1                                        1.196715e+08            12082.0
# 2                                        1.467384e+08            15229.0
# 3                                        6.179227e+06           100767.0
# 4                                        1.025810e+07            11710.0
# ..                                                ...                ...
# 95                                       6.196050e+05               33.0
# ...

# %%
# Convert X object dtype to float
X = X.astype(float)
print(X.dtypes)
# Out:
# Inhabitants                                                         float64
# GDPI                                                                float64
# Total_Amount_of_publicly_charged_electricity_energy_(kWh)           float64
# AC_points                                                           float64
# DC_points                                                           float64
# HPC_points                                                          float64
# Amount_of_Evs_in_a_wallbox_household                                float64
# Amount_of_Evs_charging_only_in_public                               float64
# Realistic_share_of_wallbox_owners                                   float64
# share_of_the_total_population_with_possibility_to_charge_at_home    float64
# AC_charging_price                                                   float64
# DC_charging_price                                                   float64
# ...

# %%
# Normalization Process
# Import min max scaler
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the data on X and y
X_scaled = scaler.fit_transform(X)
y_scaled = scaler.fit_transform(y.values.reshape(-1, 1))

# Convert the scaled data back to a DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
y_scaled_df = pd.DataFrame(y_scaled, columns=[dependent_variable])

# Display the first few rows of the scaled data
print(X_scaled_df.head())
print(y_scaled_df.head())
# Out:
#    Inhabitants      GDPI  \
# 0     1.000000  0.866258
# 1     0.097803  0.863915
# 2     0.101259  0.815135
# 3     0.806696  0.782388
# 4     0.798659  0.692759
#
#    Total_Amount_of_publicly_charged_electricity_energy_(kWh)  AC_points  \
# 0                                           0.950515           0.695029
# 1                                           0.072007           0.085741
# 2                                           0.088294           0.108135
# 3                                           0.003718           0.716825
# 4                                           0.006172           0.083094
#
#    DC_points  HPC_points  Amount_of_Evs_in_a_wallbox_household  \
# 0   1.000000    1.000000                              0.740897
# 1   0.093575    0.078625                              0.069615
# 2   0.148350    0.123712                              0.074092
# 3   0.806521    0.316852                              0.452888
# ...

# %%
# Add a constant to the independent variables matrix
X_scaled_df = sm.add_constant(X_scaled_df)

# Fit the OLS model
model = sm.OLS(y_scaled_df, X_scaled_df).fit()

# Get the summary of the model
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       EV_registrations   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     16.85
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):           6.54e-19
# Time:                        17:44:54   Log-Likelihood:                 112.25
# No. Observations:                 100   AIC:                            -194.5
# Df Residuals:                      85   BIC:                            -155.4
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
#Diagnostic Tests: 
#Check for Breusch-Pagan test for heteroscedasticity
#Chechk for White test for heteroscedasticity
#Check for Durbin-Watson test for autocorrelation
#Check for Variance inflation factor (VIF) for multicollinearity
#Check for  Robust Standard Errors for heteroscedasticity
#Check for Ramsey RESET Test (for Model Specification)

# %%
# 1. Fit the initial regression model
model = sm.OLS(y_scaled_df, X_scaled_df).fit()

# %%
# 2. Run diagnostic tests on the initial model

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan, linear_reset, het_white
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.stattools import durbin_watson

# %%
#Check for Breusch-Pagan test for heteroscedasticity
# Perform the Breusch-Pagan test
bp_test = het_breuschpagan(model.resid, model.model.exog)
print("Breusch-Pagan Test:", dict(zip(['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value'], bp_test)))
# Out:
# Breusch-Pagan Test: {'Lagrange multiplier statistic': 59.13010416458897, 'p-value': 1.6659647062646073e-07, 'f-value': 8.78407435394978, 'f p-value': 1.8861523207479855e-11}

# %%
#Check for White test for heteroscedasticity
from statsmodels.stats.diagnostic import het_white

# Perform the White test
white_test = het_white(model.resid, model.model.exog)
print(dict(zip(names, white_test)))
# Out:
# {'Lagrange multiplier statistic': 100.0, 'p-value': 0.3696681720040789, 'f-value': 2.617099463593346e+23, 'f p-value': 1.0402551933991773e-35}

# %%
#Check for Durbin-Watson test for autocorrelation
# Perform the Durbin-Watson test
dw_test = durbin_watson(model.resid)
print(f'Durbin-Watson Test: {dw_test}')
# Out:
# Durbin-Watson Test: 2.048503014695129

# %%
#Check for Variance Inflation Factor (VIF) (for Multicollinearity)
# Calculate VIF for each explanatory variable
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X_scaled_df.values, i) for i in range(X_scaled_df.shape[1])]
vif["features"] = X_scaled_df.columns
print(vif)
# Out:
#     VIF Factor                                           features
# 0    31.766406                                              const
# 1     2.938477                                        Inhabitants
# 2     1.738444                                               GDPI
# 3     6.791934  Total_Amount_of_publicly_charged_electricity_e...
# 4     2.168244                                          AC_points
# 5    12.615613                                          DC_points
# 6    12.922299                                         HPC_points
# 7     9.326213               Amount_of_Evs_in_a_wallbox_household
# 8     6.048969              Amount_of_Evs_charging_only_in_public
# 9    26.606690                  Realistic_share_of_wallbox_owners
# 10   23.574543  share_of_the_total_population_with_possibility...
# 11    2.560503                                  AC_charging_price
# 12    1.129910                                  DC_charging_price
# ...

# %%
# Check for the Ramsey RESET test for model specification
reset_test = linear_reset(model, power=2, test_type='fitted', use_f=False)
print("Ramsey RESET Test:", reset_test)
# Out:
# Ramsey RESET Test: <Wald test (chi2): statistic=14.179437973847682, p-value=0.00016617657623798837, df_denom=1>

# %%
#Check for Robust Standard Errors for heteroscedasticity
model_robust = sm.OLS(y_scaled_df, X_scaled_df).fit(cov_type='HC3')

# %%
#Print the final model summary with robust standard errors
print(model_robust.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       EV_registrations   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     12.81
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):           1.55e-15
# Time:                        18:35:45   Log-Likelihood:                 112.25
# No. Observations:                 100   AIC:                            -194.5
# Df Residuals:                      85   BIC:                            -155.4
# Df Model:                          14
# Covariance Type:                  HC3
# ...
#                                                                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
X_scaled_df['Inhabitants_squared'] = X_scaled_df['Inhabitants'] ** 2
# Add other nonlinear terms as necessary

# %%
X_scaled_df['interaction_term'] = X_scaled_df['Inhabitants'] * X_scaled_df['GDPI']

# %%
# Check for the Ramsey RESET test for model specification
reset_test = linear_reset(model, power=2, test_type='fitted', use_f=False)
print("Ramsey RESET Test:", reset_test)
# Out:
# Ramsey RESET Test: <Wald test (chi2): statistic=14.179437973847682, p-value=0.00016617657623798837, df_denom=1>

# %%
#still issue with ramsay test, trying to adress them through following steps

# %%
# Repeat for other variables as needed
#Higher order terms checked for multicollinearity and VIF


X_scaled_df['Inhabitants_squared'] = X_scaled_df['Inhabitants'] ** 2
X_scaled_df['Inhabitants_cubed'] = X_scaled_df['Inhabitants'] ** 3

# %%
#GAMs are a generalization of linear regression models that allow for non-linear relationships between the predictors and the response variable.
# %pip install pygam
from pygam import LinearGAM, s

gam = LinearGAM(s(0) + s(1) + s(2))  # Add more smooth terms based on your predictors
gam.fit(X_scaled_df, y_scaled_df)
print(gam.summary())
# Out:
# ...
#   Obtaining dependency information for pygam from https://files.pythonhosted.org/packages/ea/a7/d7037173f7c39fd114ca7bc9757149bdfbe2951b5c2cba08038c24e55e10/pygam-0.9.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for progressbar2<5.0.0,>=4.2.0 from https://files.pythonhosted.org/packages/e6/7c/7da9fefe4429f21e16fb9ab95c05f47cd11ffa4fd79932b639a1380a52a3/progressbar2-4.4.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for scipy<1.12,>=1.11.1 from https://files.pythonhosted.org/packages/5e/43/abf331745a7e5f4af51f13d40e2a72f516048db41ecbcf3ac6f86ada54a3/scipy-1.11.4-cp312-cp312-macosx_12_0_arm64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.9/217.9 kB 4.8 MB/s eta 0:00:00a 0:00:01
# ...
#   Obtaining dependency information for python-utils>=3.8.1 from https://files.pythonhosted.org/packages/26/45/98431ba6d17b99468bd3f4c53fdeefff402167f006a06773905296f6d489/python_utils-3.8.2-py2.py3-none-any.whl.metadata
# ...

# %%
print(gam.summary())
# Out:
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     14.4558
# Link Function:                     IdentityLink Log Likelihood:                                 -3172.7831
# Number of Samples:                          100 AIC:                                             6376.4778
#                                                 AICc:                                            6382.5665
#                                                 GCV:                                                0.0163
#                                                 Scale:                                              0.0121
#                                                 Pseudo R-Squared:                                   0.5563
# ...
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
for i, term in enumerate(gam.terms):
    if term.isintercept:
        continue
    plt.subplot(2, 2, i+1)
    XX = gam.generate_X_grid(term=i)
    plt.plot(XX[:, i], gam.partial_dependence(term=i, X=XX))
    plt.plot(XX[:, i], gam.partial_dependence(term=i, X=XX, width=.95)[1], c='r', ls='--')
    plt.title(f'Feature {i}')
plt.show()

# %%
# Print the final model summary with robust standard errors
print(model_robust.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       EV_registrations   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     12.81
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):           1.55e-15
# Time:                        18:23:50   Log-Likelihood:                 112.25
# No. Observations:                 100   AIC:                            -194.5
# Df Residuals:                      85   BIC:                            -155.4
# Df Model:                          14
# Covariance Type:                  HC3
# ...
#                                                                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Print the final model summary with robust standard errors
print(model_robust.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       EV_registrations   R-squared:                       0.735
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     12.81
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):           1.55e-15
# Time:                        18:23:50   Log-Likelihood:                 112.25
# No. Observations:                 100   AIC:                            -194.5
# Df Residuals:                      85   BIC:                            -155.4
# Df Model:                          14
# Covariance Type:                  HC3
# ...
#                                                                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Check that all the variables are in the DataFrame's columns
missing_columns = [var for var in independent_variables + [dependent_variable] if var not in df_combined.columns]
if missing_columns:
    print("The following columns are missing from the DataFrame: ", missing_columns)
else:
    # If all columns are present, proceed to use them in your analysis
    X = df_combined[independent_variables]
    y = df_combined[dependent_variable]
    
   # Check for non-numeric columns and convert if necessary
    X = X.apply(pd.to_numeric, errors='coerce')
    y = pd.to_numeric(y, errors='coerce')

    # Handle missing values by dropping or imputing
    X = X.dropna()
    y = y.loc[X.index]

    # Add a constant to the independent variables matrix
    X = sm.add_constant(X)

    # Perform model estimation using the OLS method
    model = sm.OLS(y, X).fit()

    # Print the summary of the estimated model
    print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       EV_registrations   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.652
# Method:                 Least Squares   F-statistic:                     9.449
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):           1.31e-09
# Time:                        15:21:46   Log-Likelihood:                -804.69
# No. Observations:                  64   AIC:                             1639.
# Df Residuals:                      49   BIC:                             1672.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
#CORRELATION ANALYSIS MATRIX USED FOR THESIS

# %%
import pandas as pd
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Convert non-numeric values to NaN and drop rows with NaN values
df_combined[independent_variables + [dependent_variable]] = df_combined[independent_variables + [dependent_variable]].apply(pd.to_numeric, errors='coerce')
df_combined.dropna(subset=[dependent_variable] + independent_variables, inplace=True)

# Extract the selected columns for correlation analysis
data_subset = df_combined[[dependent_variable] + independent_variables]

# Calculate Pearson correlation coefficients and p-values
correlation_results = {}
for var in independent_variables:
    correlation_coefficient, p_value = pearsonr(data_subset[var], data_subset[dependent_variable])
    correlation_results[var] = {'Coefficient': correlation_coefficient, 'P-value': p_value}

# Display the correlation results
print("\nPearson Correlation Coefficients for '{}' with Independent Variables:".format(dependent_variable))
for var, result in correlation_results.items():
    print("{}: Coefficient = {:.3f}, P-value = {:.3g}".format(var, result['Coefficient'], result['P-value']))

# Plotting the correlation matrix as a heatmap
correlation_matrix = data_subset.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap\n{} with Independent Variables'.format(dependent_variable))
plt.show()
# Out:
# Pearson Correlation Coefficients for 'EV_registrations' with Independent Variables:
# Inhabitants: Coefficient = 0.460, P-value = 0.00013
# GDPI: Coefficient = 0.514, P-value = 1.38e-05
# Total_Amount_of_publicly_charged_electricity_energy_(kWh): Coefficient = 0.737, P-value = 3.7e-12
# AC_points: Coefficient = 0.488, P-value = 4.26e-05
# DC_points: Coefficient = 0.706, P-value = 7.32e-11
# HPC_points: Coefficient = 0.676, P-value = 8.73e-10
# Amount_of_Evs_in_a_wallbox_household: Coefficient = 0.795, P-value = 4.39e-15
# Amount_of_Evs_charging_only_in_public: Coefficient = 0.714, P-value = 3.41e-11
# Realistic_share_of_wallbox_owners: Coefficient = 0.176, P-value = 0.164
# share_of_the_total_population_with_possibility_to_charge_at_home: Coefficient = 0.176, P-value = 0.164
# AC_charging_price: Coefficient = 0.074, P-value = 0.561
# DC_charging_price: Coefficient = 0.004, P-value = 0.972
# HPC_charging_price: Coefficient = -0.069, P-value = 0.589
# ...

# %%
import pandas as pd
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# Out:
# /var/folders/d2/6t2p0zp522l3y0s265sql42m0000gn/T/ipykernel_35590/1409864584.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Define the path to the Excel file
file_path = '/Users/user/Desktop/Thesis /Book1_python_V01.xlsx'

# %%
df = pd.read_excel(file_path)

# Display the first few rows of the dataset
print("Dataset:")
print(df.head())
# Out:
# Dataset:
#      Countries  Inhabitants      GDPI  \
# 0      Germany     84358845  33700.07
# 1  Switzerland      8815385  33608.93
# 2      Austria      9104772  31711.24
# 3       France     68172977  30437.28
# 4           UK     67500000  26950.42
#
#    Total_Amount_of_publicly_charged_electriy_energy_(kWh)  AC_points  \
# 0                                       1.579693e+09           97704
# 1                                       1.196715e+08           12082
# 2                                       1.467384e+08           15229
# 3                                       6.179227e+06          100767
# 4                                       1.025810e+07           11710
#
#    DC_points  HPC_points  Number_of_EVs  \
# 0      22921       14462        1074821
# 1       2153        1138         104088
# 2       3408        1790          92745
# 3      18488        4583         518815
# 4       6294        3998         604063
#
# ...

# %%
# Define the independent variables
Independent_variable1 = 'Inhabitants'
Independent_variable2 = 'GDPI'
Independent_variable3 = 'Total_Amount_of_publicly_charged_electricity_energy_(kWh)'  # Corrected typo
Independent_variable4 = 'AC_points'
Independent_variable5 = 'DC_points'
Independent_variable6 = 'HPC_points'
Independent_variable7 = 'Amount_of_Evs_in_a_wallbox_household'
Independent_variable8 = 'EV_registrations'
Independent_variable9 = 'Realistic_share_of_wallbox_owners'
Independent_variable10 = 'share_of_the_total_population_with_possibility_to_charge_at_home'
Independent_variable11 = 'AC_charging_price'
Independent_variable12 = 'DC_charging_price'
Independent_variable13 = 'HPC_charging_price'
Independent_variable14 = 'energy_cost'
Independent_variable15 = 'EPI score'

# Define the name of the dependent variable
dependent_variable = 'Amount_of_Evs_charging_only_in_public'

# List of all independent variables
independent_variables = [
    Independent_variable1, Independent_variable2, Independent_variable3,
    Independent_variable4, Independent_variable5, Independent_variable6,
    Independent_variable7, Independent_variable8, Independent_variable9,
    Independent_variable10, Independent_variable11, Independent_variable12,
    Independent_variable13, Independent_variable14, Independent_variable15
]

# %%
# Function to read sheet if it exists
def read_sheet(sheet_name):
    if sheet_name in sheet_names:
        return pd.read_excel(file_path, sheet_name=sheet_name)
    else:
        print(f"Worksheet named '{sheet_name}' not found.")
        return pd.DataFrame()

# Check the available sheet names in the Excel file
sheet_names = pd.ExcelFile(file_path).sheet_names

# Read data from specified sheets
df_2023 = read_sheet('2023')
df_2022 = read_sheet('2022 ')
df_2021 = read_sheet('2021')
df_2020 = read_sheet('2020')

# %%
# Combine the data into a single DataFrame
df_combined = pd.concat([df_2023, df_2022, df_2021, df_2020], ignore_index=True)

# %%
# Function to read sheet and standardize column names
def read_and_standardize_sheet(sheet_name):
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    standardized_columns = [
        'Countries', 
        'Inhabitants', 
        'GDPI',
        'Total_Amount_of_publicly_charged_electricity_energy_(kWh)', 
        'AC_points',
        'DC_points', 
        'HPC_points', 
        
        'Amount_of_Evs_charging_only_in_public', 
        'EV_registrations',
        'Realistic_share_of_wallbox_owners',
        'share_of_the_total_population_with_possibility_to_charge_at_home',
        'Kilometers_per_year_per_car_(kms.)',
        'kilometers_per_year_all_cars_(km)', 
        'EV_registrations',
        'Amount_of_cars_in_a_year',
        'Amount_of_Evs_in_a_wallbox_household', 
        'AC_charging_price',
        'DC_charging_price', 
        'HPC_charging_price', 
        'energy_cost',
        'EPI score'
    ]
    df.columns = standardized_columns
    return df

# %%
def read_and_standardize_sheet(sheet_name):
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    standardized_columns = [
        'Countries', 
        'Inhabitants', 
        'GDPI',
        'Total_Amount_of_publicly_charged_electricity_energy_(kWh)', 
        'AC_points',
        'DC_points', 
        'HPC_points', 
        
        'Amount_of_Evs_charging_only_in_public', 
        'EV_registrations',
        'Realistic_share_of_wallbox_owners',
        'share_of_the_total_population_with_possibility_to_charge_at_home',
        'Kilometers_per_year_per_car_(kms.)',
        'kilometers_per_year_all_cars_(km)', 
        'EV_registrations',
        'Amount_of_cars_in_a_year',
        'Amount_of_Evs_in_a_wallbox_household', 
        'AC_charging_price',
        'DC_charging_price', 
        'HPC_charging_price', 
        'energy_cost',
        'EPI score'
    ]
    df.columns = standardized_columns[:len(df.columns)]  # Adjust the number of columns to match the DataFrame
    return df

# %%
# Replace zeros with NaN to indicate missing data
df_combined.replace(0, pd.NA, inplace=True)

# Separate numeric columns from non-numeric columns
numeric_columns = df_combined.select_dtypes(include=['number']).columns
non_numeric_columns = df_combined.select_dtypes(exclude=['number']).columns

# Fill missing values in numeric columns with the mean
df_combined[numeric_columns] = df_combined[numeric_columns].fillna(df_combined[numeric_columns].mean())

# Fill missing values in non-numeric columns with a placeholder or the most frequent value
df_combined[non_numeric_columns] = df_combined[non_numeric_columns].fillna('Unknown')

# %%
# Rename columns from Total_Amount_of_publicly_charged_electriy_energy_(kWh) to Total_Amount_of_publicly_charged_electricity_energy_(kWh)
# Rename columns from share_of_the_total_population_with_possiblity_to_charge_at_home to share_of_the_total_population_with_possibility_to_charge_at_home
df_combined.rename(columns={'Total_Amount_of_publicly_charged_electriy_energy_(kWh)': 'Total_Amount_of_publicly_charged_electricity_energy_(kWh)',
                            'share_of_the_total_population_with_possiblity_to_charge_at_home': 'share_of_the_total_population_with_possibility_to_charge_at_home'}, inplace=True)

# %%
# Check that all the variables are in the DataFrame's columns
missing_columns = [var for var in independent_variables + [dependent_variable] if var not in df_combined.columns]
if missing_columns:
    print("The following columns are missing from the DataFrame: ", missing_columns)
else:
    # If all columns are present, proceed to use them in your analysis
    X = df_combined[independent_variables]
    y = df_combined[dependent_variable]
    
   # Check for non-numeric columns and convert if necessary
    X = X.apply(pd.to_numeric, errors='coerce')
    y = pd.to_numeric(y, errors='coerce')

    # Handle missing values by dropping or imputing
    X = X.dropna()
    y = y.loc[X.index]

    # Add a constant to the independent variables matrix
    X = sm.add_constant(X)

    # Perform model estimation using the OLS method
    model = sm.OLS(y, X).fit()

    # Print the summary of the estimated model
    print(model.summary())
# Out:
#                                       OLS Regression Results
# ...
# Dep. Variable:     Amount_of_Evs_charging_only_in_public   R-squared:                       0.892
# Model:                                               OLS   Adj. R-squared:                  0.859
# Method:                                    Least Squares   F-statistic:                     26.48
# Date:                                   Mon, 08 Jul 2024   Prob (F-statistic):           3.78e-18
# Time:                                           15:20:35   Log-Likelihood:                -770.15
# No. Observations:                                     64   AIC:                             1572.
# Df Residuals:                                         48   BIC:                             1607.
# Df Model:                                             15
# Covariance Type:                               nonrobust
# ...

# %%
import pandas as pd
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Convert non-numeric values to NaN and drop rows with NaN values
df_combined[independent_variables + [dependent_variable]] = df_combined[independent_variables + [dependent_variable]].apply(pd.to_numeric, errors='coerce')
df_combined.dropna(subset=[dependent_variable] + independent_variables, inplace=True)

# Extract the selected columns for correlation analysis
data_subset = df_combined[[dependent_variable] + independent_variables]

# Calculate Pearson correlation coefficients and p-values
correlation_results = {}
for var in independent_variables:
    correlation_coefficient, p_value = pearsonr(data_subset[var], data_subset[dependent_variable])
    correlation_results[var] = {'Coefficient': correlation_coefficient, 'P-value': p_value}

# Display the correlation results
print("\nPearson Correlation Coefficients for '{}' with Independent Variables:".format(dependent_variable))
for var, result in correlation_results.items():
    print("{}: Coefficient = {:.3f}, P-value = {:.3g}".format(var, result['Coefficient'], result['P-value']))

# Plotting the correlation matrix as a heatmap
correlation_matrix = data_subset.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap\n{} with Independent Variables'.format(dependent_variable))
plt.show()
# Out:
# Pearson Correlation Coefficients for 'Amount_of_Evs_charging_only_in_public' with Independent Variables:
# Inhabitants: Coefficient = 0.475, P-value = 7.23e-05
# GDPI: Coefficient = 0.564, P-value = 1.21e-06
# Total_Amount_of_publicly_charged_electricity_energy_(kWh): Coefficient = 0.909, P-value = 3.16e-25
# AC_points: Coefficient = 0.496, P-value = 3.09e-05
# DC_points: Coefficient = 0.795, P-value = 4.29e-15
# HPC_points: Coefficient = 0.835, P-value = 9.94e-18
# Amount_of_Evs_in_a_wallbox_household: Coefficient = 0.842, P-value = 3.01e-18
# EV_registrations: Coefficient = 0.714, P-value = 3.41e-11
# Realistic_share_of_wallbox_owners: Coefficient = -0.007, P-value = 0.958
# share_of_the_total_population_with_possibility_to_charge_at_home: Coefficient = -0.007, P-value = 0.958
# AC_charging_price: Coefficient = 0.039, P-value = 0.757
# DC_charging_price: Coefficient = -0.053, P-value = 0.678
# HPC_charging_price: Coefficient = -0.071, P-value = 0.578
# ...

# %%
import pandas as pd
import statsmodels.api as sm

# Check that all the variables are in the DataFrame's columns
missing_columns = [var for var in independent_variables + [dependent_variable] if var not in df_combined.columns]
if missing_columns:
    print("The following columns are missing from the DataFrame: ", missing_columns)
else:
    # If all columns are present, proceed to use them in your analysis
    X = df_combined[independent_variables]
    y = df_combined[dependent_variable]
    
    # Check for non-numeric columns and convert if necessary
    X = X.apply(pd.to_numeric, errors='coerce')
    y = pd.to_numeric(y, errors='coerce')

    # Handle missing values by dropping or imputing
    X = X.dropna()
    y = y.loc[X.index]

    # Add a constant to the independent variables matrix
    X = sm.add_constant(X)

    # Perform model estimation using the OLS method
    model = sm.OLS(y, X).fit()

    # Print the summary of the estimated model
    print(model.summary())

# Define the independent variables
Independent_variable1 = 'Inhabitants'
Independent_variable2 = 'GDPI'
Independent_variable3 = 'Total_Amount_of_publicly_charged_electricity_energy_(kWh)'  # Corrected typo
Independent_variable4 = 'AC_points'
Independent_variable5 = 'DC_points'
Independent_variable6 = 'HPC_points'
Independent_variable7 = 'Amount_of_Evs_in_a_wallbox_household'
Independent_variable8 = 'EV_registrations'
Independent_variable9 = 'Realistic_share_of_wallbox_owners'
Independent_variable10 = 'share_of_the_total_population_with_possibility_to_charge_at_home'
Independent_variable11 = 'AC_charging_price'
Independent_variable12 = 'DC_charging_price'
Independent_variable13 = 'HPC_charging_price'
Independent_variable14 = 'energy_cost'
Independent_variable15 = 'EPI_score'  # Corrected to match Python variable naming convention

# Define the name of the dependent variable
dependent_variable = 'Amount_of_Evs_charging_only_in_public'

# List of all independent variables
independent_variables = [
    Independent_variable1, Independent_variable2, Independent_variable3,
    Independent_variable4, Independent_variable5, Independent_variable6,
    Independent_variable7, Independent_variable8, Independent_variable9,
    Independent_variable10, Independent_variable11, Independent_variable12,
    Independent_variable13, Independent_variable14, Independent_variable15
]
# Out:
#                                       OLS Regression Results
# ...
# Dep. Variable:     Amount_of_Evs_charging_only_in_public   R-squared:                       0.892
# Model:                                               OLS   Adj. R-squared:                  0.859
# Method:                                    Least Squares   F-statistic:                     26.48
# Date:                                   Mon, 08 Jul 2024   Prob (F-statistic):           3.78e-18
# Time:                                           15:53:49   Log-Likelihood:                -770.15
# No. Observations:                                     64   AIC:                             1572.
# Df Residuals:                                         48   BIC:                             1607.
# Df Model:                                             15
# Covariance Type:                               nonrobust
# ...

# %%
import pandas as pd
import statsmodels.api as sm

# Define the independent variables excluding 'EPI_score'
Independent_variable1 = 'Inhabitants'
Independent_variable2 = 'GDPI'
Independent_variable3 = 'Total_Amount_of_publicly_charged_electricity_energy_(kWh)'  # Corrected typo
Independent_variable4 = 'AC_points'
Independent_variable5 = 'DC_points'
Independent_variable6 = 'HPC_points'
Independent_variable7 = 'Amount_of_Evs_in_a_wallbox_household'
Independent_variable8 = 'EV_registrations'
Independent_variable9 = 'Realistic_share_of_wallbox_owners'
Independent_variable10 = 'share_of_the_total_population_with_possibility_to_charge_at_home'
Independent_variable11 = 'AC_charging_price'
Independent_variable12 = 'DC_charging_price'
Independent_variable13 = 'HPC_charging_price'
Independent_variable14 = 'energy_cost'

# Define the name of the dependent variable
dependent_variable = 'Amount_of_Evs_charging_only_in_public'

# List of all independent variables excluding 'EPI_score'
independent_variables = [
    Independent_variable1, Independent_variable2, Independent_variable3,
    Independent_variable4, Independent_variable5, Independent_variable6,
    Independent_variable7, Independent_variable8, Independent_variable9,
    Independent_variable10, Independent_variable11, Independent_variable12,
    Independent_variable13, Independent_variable14
]

# Check that all the variables are in the DataFrame's columns
missing_columns = [var for var in independent_variables + [dependent_variable] if var not in df_combined.columns]
if missing_columns:
    print("The following columns are missing from the DataFrame: ", missing_columns)
else:
    # If all columns are present, proceed to use them in your analysis
    X = df_combined[independent_variables]
    y = df_combined[dependent_variable]
    
    # Check for non-numeric columns and convert if necessary
    X = X.apply(pd.to_numeric, errors='coerce')
    y = pd.to_numeric(y, errors='coerce')

    # Handle missing values by dropping or imputing
    X = X.dropna()
    y = y.loc[X.index]

    # Add a constant to the independent variables matrix
    X = sm.add_constant(X)

    # Perform model estimation using the OLS method
    model = sm.OLS(y, X).fit()

    # Print the summary of the estimated model
    print(model.summary())
# Out:
#                                       OLS Regression Results
# ...
# Dep. Variable:     Amount_of_Evs_charging_only_in_public   R-squared:                       0.890
# Model:                                               OLS   Adj. R-squared:                  0.859
# Method:                                    Least Squares   F-statistic:                     28.42
# Date:                                   Mon, 08 Jul 2024   Prob (F-statistic):           1.03e-18
# Time:                                           17:06:03   Log-Likelihood:                -770.70
# No. Observations:                                     64   AIC:                             1571.
# Df Residuals:                                         49   BIC:                             1604.
# Df Model:                                             14
# Covariance Type:                               nonrobust
# ...

# %%
# Convert non-numeric values to NaN and drop rows with NaN values
df_combined[independent_variables + [dependent_variable]] = df_combined[independent_variables + [dependent_variable]].apply(pd.to_numeric, errors='coerce')
df_combined.dropna(subset=[dependent_variable] + independent_variables, inplace=True)

# Extract the selected columns for correlation analysis
data_subset = df_combined[[dependent_variable] + independent_variables]

# Calculate Pearson correlation coefficients and p-values
correlation_results = {}
for var in independent_variables:
    correlation_coefficient, p_value = pearsonr(data_subset[var], data_subset[dependent_variable])
    correlation_results[var] = {'Coefficient': correlation_coefficient, 'P-value': p_value}

# Display the correlation results
print("\nPearson Correlation Coefficients for '{}' with Independent Variables:".format(dependent_variable))
for var, result in correlation_results.items():
    print("{}: Coefficient = {:.3f}, P-value = {:.3g}".format(var, result['Coefficient'], result['P-value']))

# Plotting the correlation matrix as a heatmap
correlation_matrix = data_subset.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap\n{} with Independent Variables'.format(dependent_variable))
plt.show()
# Out:
# Pearson Correlation Coefficients for 'Amount_of_Evs_charging_only_in_public' with Independent Variables:
# Inhabitants: Coefficient = 0.475, P-value = 7.23e-05
# GDPI: Coefficient = 0.564, P-value = 1.21e-06
# Total_Amount_of_publicly_charged_electricity_energy_(kWh): Coefficient = 0.909, P-value = 3.16e-25
# AC_points: Coefficient = 0.496, P-value = 3.09e-05
# DC_points: Coefficient = 0.795, P-value = 4.29e-15
# HPC_points: Coefficient = 0.835, P-value = 9.94e-18
# Amount_of_Evs_in_a_wallbox_household: Coefficient = 0.842, P-value = 3.01e-18
# EV_registrations: Coefficient = 0.714, P-value = 3.41e-11
# Realistic_share_of_wallbox_owners: Coefficient = -0.007, P-value = 0.958
# share_of_the_total_population_with_possibility_to_charge_at_home: Coefficient = -0.007, P-value = 0.958
# AC_charging_price: Coefficient = 0.039, P-value = 0.757
# DC_charging_price: Coefficient = -0.053, P-value = 0.678
# HPC_charging_price: Coefficient = -0.071, P-value = 0.578
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Load your dataset
file_path = '/Users/user/Desktop/Thesis /Book1_python_V01.xlsx'  # Define the path to the Excel file
data = pd.read_excel(file_path, engine='openpyxl')

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# List of columns to normalize
columns_to_normalize = [
    'Inhabitants', 'GDPI', 'Total_Amount_of_publicly_charged_electricity_energy_(kWh)',
    'AC_points', 'DC_points', 'HPC_points', 'Number_of_EVs',
    'Amount_of_EVs_charging_only_in_public', 'EV_registrations',
    'Realistic_share_of_wallbox_owners', 'share_of_the_total_population_with_possibility_to_charge_at_home',
    'Kilometers_per_year_per_car_(kms.)', 'kilometers_per_year_all_cars_(km)',
    'Amount_of_cars_in_a_year', 'Amount_of_EVs_in_a_wallbox_household',
    'AC_charging_price', 'DC_charging_price', 'HPC_charging_price', 'energy_cost', 'EPI score'
]

# Apply Min-Max scaling to the specified columns
data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])

# Save the normalized data to a new Excel file
normalized_file_path = '/Users/user/Desktop/Thesis/normalized_data.xlsx'
data.to_excel(normalized_file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 23
#      12 columns_to_normalize = [
#      13     'Inhabitants', 'GDPI', 'Total_Amount_of_publicly_charged_electricity_energy_(kWh)',
#      14     'AC_points', 'DC_points', 'HPC_points', 'Number_of_EVs',
#    (...)
#      19     'AC_charging_price', 'DC_charging_price', 'HPC_charging_price', 'energy_cost', 'EPI score'
#      20 ]
#      22 # Apply Min-Max scaling to the specified columns
# ---> 23 data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])
#      25 # Save the normalized data to a new Excel file
#      26 normalized_file_path = '/Users/user/Desktop/Thesis/normalized_data.xlsx'
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
# ...

# %%
# Define the path to the Excel file
file_path = '/Users/user/Desktop/Thesis /Book1_python_V01.xlsx'

# %%
# Define the independent variables
Independent_variable1 = 'Inhabitants'
Independent_variable2 = 'GDPI'
Independent_variable3 = 'Total_Amount_of_publicly_charged_electricity_energy_(kWh)'  # Corrected typo
Independent_variable4 = 'AC_points'
Independent_variable5 = 'DC_points'
Independent_variable6 = 'HPC_points'
Independent_variable7 = 'Amount_of_Evs_in_a_wallbox_household'
Independent_variable8 = 'EV_registrations'
Independent_variable9 = 'Realistic_share_of_wallbox_owners'
Independent_variable10 = 'share_of_the_total_population_with_possibility_to_charge_at_home'
Independent_variable11 = 'AC_charging_price'
Independent_variable12 = 'DC_charging_price'
Independent_variable13 = 'HPC_charging_price'
Independent_variable14 = 'energy_cost'
Independent_variable15 = 'EPI score'

# Define the name of the dependent variable
dependent_variable = 'Amount_of_Evs_charging_only_in_public'

# List of all independent variables
independent_variables = [
    Independent_variable1, Independent_variable2, Independent_variable3,
    Independent_variable4, Independent_variable5, Independent_variable6,
    Independent_variable7, Independent_variable8, Independent_variable9,
    Independent_variable10, Independent_variable11, Independent_variable12,
    Independent_variable13, Independent_variable14, Independent_variable15
]

# %%
# Function to read sheet if it exists
def read_sheet(sheet_name):
    if sheet_name in sheet_names:
        return pd.read_excel(file_path, sheet_name=sheet_name)
    else:
        print(f"Worksheet named '{sheet_name}' not found.")
        return pd.DataFrame()

# Check the available sheet names in the Excel file
sheet_names = pd.ExcelFile(file_path).sheet_names

# Read data from specified sheets
df_2023 = read_sheet('2023')
df_2022 = read_sheet('2022 ')
df_2021 = read_sheet('2021')
df_2020 = read_sheet('2020')

# %%
import os
import matplotlib.pyplot as plt

# Create a simple S-curve diagram
# Change the directory to a writable location
directory = '/tmp/data'
if not os.path.exists(directory):
    os.makedirs(directory)

# %%
import os
import matplotlib.pyplot as plt

# Create a simple S-curve diagram
plt.figure(figsize=(8, 5))
x = [i for i in range(1, 101)]
y = [1 / (1 + 100 * 2.718 ** (-0.1 * (i - 50))) for i in x]
# Create the directory if it does not exist
directory = '/Users/user/Desktop/Thesis'
if not os.path.exists(directory):
    os.makedirs(directory)
plt.grid(True)

# Save the diagram as an image file
file_path = '/Users/user/Desktop/Thesis/Innovation_S_Curve_Simple_v2.png'
plt.savefig(file_path)
plt.close()

file_path
# Out:
# '/Users/user/Desktop/Thesis/Innovation_S_Curve_Simple_v2.png'

# %%
# Define the path to the Excel file
file_path = '/Users/user/Desktop/Thesis /Book1_python_V001.xlsx'

# %%
import pandas as pd
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
df = pd.read_excel(file_path)

# Display the first few rows of the dataset
print("Dataset:")
print(df.head())
# Out:
# Dataset:
#      Countries  Inhabitants      GDPI  \
# 0      Germany     84358845  33700.07
# 1  Switzerland      8815385  33608.93
# 2      Austria      9104772  31711.24
# 3       France     68172977  30437.28
# 4           UK     67500000  26950.42
#
#    Total_Amount_of_publicly_charged_electriy_energy_(kWh)  AC_points  \
# 0                                       1.579693e+09           97704
# 1                                       1.196715e+08           12082
# 2                                       1.467384e+08           15229
# 3                                       6.179227e+06          100767
# 4                                       1.025810e+07           11710
#
#    DC_points  HPC_points  Number_of_EVs  \
# 0      22921       14462        1074821
# 1       2153        1138         104088
# 2       3408        1790          92745
# 3      18488        4583         518815
# 4       6294        3998         604063
#
# ...

# %%
# Function to read sheet if it exists
def read_sheet(sheet_name):
    if sheet_name in sheet_names:
        return pd.read_excel(file_path, sheet_name=sheet_name)
    else:
        print(f"Worksheet named '{sheet_name}' not found.")
        return pd.DataFrame()

# Check the available sheet names in the Excel file
sheet_names = pd.ExcelFile(file_path).sheet_names

# Read data from specified sheets
df_2023 = read_sheet('2023')
df_2022 = read_sheet('2022 ')
df_2021 = read_sheet('2021')
df_2020 = read_sheet('2020')

# %%
# Combine the data into a single DataFrame
df_combined = pd.concat([df_2023, df_2022, df_2021, df_2020], ignore_index=True)

# %%
# Rename columns from Total_Amount_of_publicly_charged_electriy_energy_(kWh) to Total_Amount_of_publicly_charged_electricity_energy_(kWh)
# Rename columns from share_of_the_total_population_with_possiblity_to_charge_at_home to share_of_the_total_population_with_possibility_to_charge_at_home
df_combined.rename(columns={'Total_Amount_of_publicly_charged_electriy_energy_(kWh)': 'Total_Amount_of_publicly_charged_electricity_energy_(kWh)',
                            'share_of_the_total_population_with_possiblity_to_charge_at_home': 'share_of_the_total_population_with_possibility_to_charge_at_home'}, inplace=True)

# %%
# Count the number of observations for a specific variable (e.g., 'Inhabitants')
variable_name = 'Inhabitants'
observation_count = df_combined[variable_name].count()

# Display the result
print(f"Number of observations for '{variable_name}': {observation_count}")
# Out:
# Number of observations for 'Inhabitants': 96

# %%
print("Dataset:")
print(df.head())
# Out:
# Dataset:
#      Countries  Inhabitants      GDPI  \
# 0      Germany     84358845  33700.07
# 1  Switzerland      8815385  33608.93
# 2      Austria      9104772  31711.24
# 3       France     68172977  30437.28
# 4           UK     67500000  26950.42
#
#    Total_Amount_of_publicly_charged_electriy_energy_(kWh)  AC_points  \
# 0                                       1.579693e+09           97704
# 1                                       1.196715e+08           12082
# 2                                       1.467384e+08           15229
# 3                                       6.179227e+06          100767
# 4                                       1.025810e+07           11710
#
#    DC_points  HPC_points  Number_of_EVs  \
# 0      22921       14462        1074821
# 1       2153        1138         104088
# 2       3408        1790          92745
# 3      18488        4583         518815
# 4       6294        3998         604063
#
# ...

# %%
import pandas as pd

# Replace 'Inhabitants' with the specific variable/column name you want to analyze
variable_name = 'Inhabitants'

# Filter out 0 values and handle missing values by dropping them
filtered_data = df_combined[variable_name].replace(0, pd.NA).dropna()

# Calculate the required statistics
mean_value = filtered_data.mean()
median_value = filtered_data.median()
std_dev = filtered_data.std()
min_value = filtered_data.min()
max_value = filtered_data.max()

# Format the results in European number system (comma as decimal separator, period as thousand separator)
mean_value_formatted = f"{mean_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
median_value_formatted = f"{median_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
std_dev_formatted = f"{std_dev:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
min_value_formatted = f"{min_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
max_value_formatted = f"{max_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")

# Display the results
print(f"Mean (excluding 0s): {mean_value_formatted}")
print(f"Median (excluding 0s): {median_value_formatted}")
print(f"Standard Deviation (excluding 0s): {std_dev_formatted}")
print(f"Minimum (excluding 0s): {min_value_formatted}")
print(f"Maximum (excluding 0s): {max_value_formatted}")
# Out:
# Mean (excluding 0s): 20.298.758,89
# Median (excluding 0s): 9.352.258,00
# Standard Deviation (excluding 0s): 24.788.343,57
# Minimum (excluding 0s): 626.100,00
# Maximum (excluding 0s): 84.358.845,00

# %%
import pandas as pd

# Function to calculate statistics while ignoring zeros and handling missing values
def calculate_statistics(df, variable_name):
    # Filter out 0 values and handle missing values
    filtered_data = df[variable_name][df[variable_name] != 0].dropna()

    # Calculate statistics
    overall_mean = filtered_data.mean()
    overall_median = filtered_data.median()
    overall_std = filtered_data.std()
    overall_min = filtered_data.min()
    overall_max = filtered_data.max()

    # Format the results in European number system
    formatted_mean = f"{overall_mean:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_median = f"{overall_median:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_std = f"{overall_std:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_min = f"{overall_min:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_max = f"{overall_max:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")

    # Display the results
    print(f"Overall Mean for '{variable_name}': {formatted_mean}")
    print(f"Overall Median for '{variable_name}': {formatted_median}")
    print(f"Overall Standard Deviation for '{variable_name}': {formatted_std}")
    print(f"Overall Minimum for '{variable_name}': {formatted_min}")
    print(f"Overall Maximum for '{variable_name}': {formatted_max}")

#

# %%
variable_name = 'Inhabitants'  # Replace with your specific variable name
calculate_statistics(df_combined, variable_name)
# Out:
# Overall Mean for 'Inhabitants': 20.298.758,89
# Overall Median for 'Inhabitants': 9.352.258,00
# Overall Standard Deviation for 'Inhabitants': 24.788.343,57
# Overall Minimum for 'Inhabitants': 626.100,00
# Overall Maximum for 'Inhabitants': 84.358.845,00

# %%
import pandas as pd

# Function to calculate statistics while ignoring zeros and handling missing values
def calculate_statistics(df, variable_name):
    # Filter out 0 values and handle missing values
    filtered_data = df[variable_name][df[variable_name] != 0].dropna()

    # Calculate statistics
    mean_value = filtered_data.mean()
    median_value = filtered_data.median()
    std_value = filtered_data.std()
    min_value = filtered_data.min()
    max_value = filtered_data.max()

    # Format the results in European number system
    formatted_mean = f"{mean_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_median = f"{median_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_std = f"{std_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_min = f"{min_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_max = f"{max_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")

    # Display the results
    print(f"Mean for '{variable_name}': {formatted_mean}")
    print(f"Median for '{variable_name}': {formatted_median}")
    print(f"Standard Deviation for '{variable_name}': {formatted_std}")
    print(f"Minimum for '{variable_name}': {formatted_min}")
    print(f"Maximum for '{variable_name}': {formatted_max}")

# %%
variable_name = 'GDPI'  # Replace with your specific variable name
calculate_statistics(df_combined, variable_name)
# Out:
# Mean for 'GDPI': 24.778,57
# Median for 'GDPI': 24.743,09
# Standard Deviation for 'GDPI': 5.457,93
# Minimum for 'GDPI': 15.591,00
# Maximum for 'GDPI': 38.903,05

# %%
import pandas as pd

# Function to calculate statistics while ignoring zeros and handling missing values
def calculate_statistics(df, variable_name):
    # Filter out 0 values and handle missing values
    filtered_data = df[variable_name][df[variable_name] != 0].dropna()

    # Calculate statistics
    mean_value = filtered_data.mean()
    median_value = filtered_data.median()
    std_value = filtered_data.std()
    min_value = filtered_data.min()
    max_value = filtered_data.max()
    total_observations = filtered_data.count()  # Total number of valid observations

    # Format the results in European number system
    formatted_mean = f"{mean_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_median = f"{median_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_std = f"{std_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_min = f"{min_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_max = f"{max_value:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    formatted_observations = f"{total_observations:,}".replace(",", ".")

    # Display the results
    print(f"Total Observations for '{variable_name}': {formatted_observations}")
    print(f"Mean for '{variable_name}': {formatted_mean}")
    print(f"Median for '{variable_name}': {formatted_median}")
    print(f"Standard Deviation for '{variable_name}': {formatted_std}")
    print(f"Minimum for '{variable_name}': {formatted_min}")
    print(f"Maximum for '{variable_name}': {formatted_max}")

# %%
variable_name = 'Amount_of_Evs_charging_only_in_public'  # Replace with your specific variable name
calculate_statistics(df_combined, variable_name)
# Out:
# Total Observations for 'Amount_of_Evs_charging_only_in_public': 96
# Mean for 'Amount_of_Evs_charging_only_in_public': 69.675,61
# Median for 'Amount_of_Evs_charging_only_in_public': 17.221,57
# Standard Deviation for 'Amount_of_Evs_charging_only_in_public': 123.937,77
# Minimum for 'Amount_of_Evs_charging_only_in_public': 216,71
# Maximum for 'Amount_of_Evs_charging_only_in_public': 597.267,00

# %%
# Define the independent variables
Independent_variable1 = 'Inhabitants'
Independent_variable2 = 'GDPI'
Independent_variable3 = 'Total_Amount_of_publicly_charged_electricity_energy_(kWh)'  # Corrected typo
Independent_variable4 = 'AC_points'
Independent_variable5 = 'DC_points'
Independent_variable6 = 'HPC_points'
Independent_variable7 = 'Amount_of_Evs_in_a_wallbox_household'
Independent_variable8 = 'Amount_of_Evs_charging_only_in_public'
Independent_variable9 = 'Realistic_share_of_wallbox_owners'
Independent_variable10 = 'share_of_the_total_population_with_possibility_to_charge_at_home'
Independent_variable11 = 'AC_charging_price'
Independent_variable12 = 'DC_charging_price'
Independent_variable13 = 'HPC_charging_price'
Independent_variable14 = 'energy_cost'
Independent_variable15 = 'EPI score'

# Define the name of the dependent variable
dependent_variable = 'EV_registrations'

# List of all independent variables
independent_variables = [
    Independent_variable1, Independent_variable2, Independent_variable3,
    Independent_variable4, Independent_variable5, Independent_variable6,
    Independent_variable7, Independent_variable8, Independent_variable9,
    Independent_variable10, Independent_variable11, Independent_variable12,
    Independent_variable13, Independent_variable14
]

# %%
import pandas as pd

# Function to calculate statistics while ignoring zeros and handling missing values
def calculate_statistics(df, variable_name):
    # Filter out 0 values and handle missing values
    filtered_data = df[variable_name][df[variable_name] != 0].dropna()

    # Calculate statistics
    mean_value = filtered_data.mean()
    median_value = filtered_data.median()
    std_value = filtered_data.std()
    min_value = filtered_data.min()
    max_value = filtered_data.max()
    total_observations = filtered_data.count()  # Total number of valid observations

    # Format the results in US/UK (English) number system
    formatted_mean = f"{mean_value:,.2f}"
    formatted_median = f"{median_value:,.2f}"
    formatted_std = f"{std_value:,.2f}"
    formatted_min = f"{min_value:,.2f}"
    formatted_max = f"{max_value:,.2f}"
    formatted_observations = f"{total_observations:,}"

    # Display the results
    print(f"Total Observations for '{variable_name}': {formatted_observations}")
    print(f"Mean for '{variable_name}': {formatted_mean}")
    print(f"Median for '{variable_name}': {formatted_median}")
    print(f"Standard Deviation for '{variable_name}': {formatted_std}")
    print(f"Minimum for '{variable_name}': {formatted_min}")
    print(f"Maximum for '{variable_name}': {formatted_max}")

# %%
variable_name = 'DC_charging_price'  # Replace with your specific variable name
calculate_statistics(df_combined, variable_name)
# Out:
# Total Observations for 'DC_charging_price': 90
# Mean for 'DC_charging_price': 12.24
# Median for 'DC_charging_price': 0.57
# Standard Deviation for 'DC_charging_price': 110.62
# Minimum for 'DC_charging_price': 0.22
# Maximum for 'DC_charging_price': 1,050.00
